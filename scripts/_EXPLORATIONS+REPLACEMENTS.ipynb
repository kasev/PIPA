# %% [markdown]
# **Make sure that you are connected to the kernel associated with our virtual environment . Go to `Kernel` -> `Change kernel` and choose `pia_venv`.**

# %%
### REQUIREMENTS

import pandas as pd
import re

# %%
### load our data
c_hippocraticum = pd.read_json("../data/c_hippocraticum.json")
c_platonicum = pd.read_json("../data/c_platonicum.json")
c_aristotelicum = pd.read_json("../data/c_aristotelicum.json")

# %% [markdown]
# # Key term replacement

# %%
### produce a list of all words from the authors
### (useful for a preliminary exploration)
aristotle_list = []
for list_element in c_aristotelicum["lemmata"].tolist():
  aristotle_list.extend(list_element)

plato_list = []
for list_element in c_platonicum["lemmata"].tolist():
  plato_list.extend(list_element)

hippocrates_list = []
for list_element in c_hippocraticum["lemmata"].tolist():
  hippocrates_list.extend(list_element)
one_merged_list = aristotle_list + plato_list + hippocrates_list

# %%
# manually define key terms we are interested in:
keyterm_patterns = [("^λ[υ|ύ]π.+", "λύπ*"), ("[α|ά|ἀ|ἄ]λγ.+", "ἄλγ*"), ("^[ὀ|ὠ]δ[ύ|υ]ν.", "ὀδύν*"), ("^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+", "πόνο*")]

# %%
# unique word forms
matches = []
for pattern_tuple in keyterm_patterns:
  r = re.compile(pattern_tuple[0])
  matches.extend([(pattern_tuple[0], pattern_tuple[1], match, aristotle_list.count(match), plato_list.count(match), hippocrates_list.count(match)) for match in list(filter(r.search, list(set(aristotle_list + hippocrates_list))))])
matches_df = pd.DataFrame(matches, columns=["pattern", "replacement", "match", "c_aristotelicum", "c_platonicum", "c_hippocraticum"]) #, "translation"])
matches_df
# Out:
#                             pattern replacement      match  c_aristotelicum  \
# 0                        ^λ[υ|ύ]π.+        λύπ*  λυπέουσιν                0
# 1                        ^λ[υ|ύ]π.+        λύπ*    λυπηρός               83
# 2                        ^λ[υ|ύ]π.+        λύπ*      λυπέω              113
# 3                        ^λ[υ|ύ]π.+        λύπ*   λυπέοντα                0
# 4                        ^λ[υ|ύ]π.+        λύπ*   λυπεῖταἰ                1
# ..                              ...         ...        ...              ...
# 157  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*  πονέουσαι                0
# 158  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*  πονεούσης                0
# 159  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*   πονητικὰ                1
# 160  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*   πονέεται                0
# 161  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*   πονέουσα                0
#
#      c_platonicum  c_hippocraticum
# 0               0                1
# 1              21                3
# 2              50               16
# 3               0                3
# 4               0                0
# ..            ...              ...
# 157             0                2
# 158             0                1
# 159             0                0
# 160             0                7
# 161             0                2
#
# [162 rows x 6 columns]

# %%
matches_df.to_csv("../data/matches_pain_words.csv")

# %%
# use these regular expressions to make replacements in the list of lemmata
def replacer_word_list(pattern, product, word_list):
  return [re.sub(pattern, product, word) for word in word_list]

def replace_keywords(list_of_words, list_of_tuples):
  for pattern in list_of_tuples:
    list_of_words = replacer_word_list(pattern[0], pattern[1], list_of_words)
  return list_of_words

# %%
### test (includes artificial words):
word_list_test = ['βοοκ', 'πᾶς', 'μέλυπρᾷ', "ἄλγτέχνη",'τέχνη' ,'πᾶς', 'μέθοδος', 'ὅμοιος', "λύπη",'πρᾶξίς', 'προαίρεσις', 'ἀγαθός', 'ἐφίημι']
replace_keywords(word_list_test, keyterm_patterns)
# Out:
# ['βοοκ',
#  'πᾶς',
#  'μέλυπρᾷ',
#  'ἄλγ*',
#  'τέχνη',
#  'πᾶς',
#  'μέθοδος',
#  'ὅμοιος',
#  'λύπ*',
#  'πρᾶξίς',
#  'προαίρεσις',
#  'ἀγαθός',
#  'ἐφίημι']

# %%
# apply the replacement on the level of individual words
c_aristotelicum["lemmata_repl"] = c_aristotelicum["lemmata"].apply(lambda x: replace_keywords(x, keyterm_patterns))
c_platonicum["lemmata_repl"] = c_platonicum["lemmata"].apply(lambda x: replace_keywords(x, keyterm_patterns))
c_hippocraticum["lemmata_repl"] = c_hippocraticum["lemmata"].apply(lambda x: replace_keywords(x, keyterm_patterns))

# %%
# apply the replacement on the sentences
def replace_in_sentences(list_of_sentences):
    return [replace_keywords(sentence, keyterm_patterns) for sentence in list_of_sentences]

c_aristotelicum["lemmatized_sentences_repl"] = c_aristotelicum["lemmatized_sentences"].apply(replace_in_sentences)
c_platonicum["lemmatized_sentences_repl"] = c_platonicum["lemmatized_sentences"].apply(replace_in_sentences)
c_hippocraticum["lemmatized_sentences_repl"] = c_hippocraticum["lemmatized_sentences"].apply(replace_in_sentences)

# %%
c_platonicum.head(5)
# Out:
#                             filename author      title  wordcount author_id  \
# 535  tlg0059.tlg001.perseus-grc1.xml  Plato  Euthyphro       5393   tlg0059
# 536  tlg0059.tlg002.perseus-grc2.xml  Plato    Apology       8659   tlg0059
# 537  tlg0059.tlg003.perseus-grc2.xml  Plato      Crito       4268   tlg0059
# 538  tlg0059.tlg004.perseus-grc2.xml  Plato     Phaedo      22519   tlg0059
# 539  tlg0059.tlg005.perseus-grc2.xml  Plato   Cratylus      18985   tlg0059
#
#              doc_id  raw_date  date_avr                  date_probs  \
# 535  tlg0059.tlg001  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}
# 536  tlg0059.tlg002  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}
# 537  tlg0059.tlg003  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}
# 538  tlg0059.tlg004  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}
# 539  tlg0059.tlg005  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}
#
#      date_manual provenience       tlg_epithet  \
# 535         -3.5       pagan  Philosophici/-ae
# 536         -3.5       pagan  Philosophici/-ae
# 537         -3.5       pagan  Philosophici/-ae
# 538         -3.5       pagan  Philosophici/-ae
# 539         -3.5       pagan  Philosophici/-ae
#
#                                           clean_string  n_sentences  \
# 535  ΕΥΘ. τί νεώτερον, ὦ Σώκρατες, γέγονεν, ὅτι σὺ ...          659
# 536   ὅτι μὲν ὑμεῖς, ὦ ἄνδρες Ἀθηναῖοι, πεπόνθατε ὑ...          483
# 537   ΣΩ. τί τηνικάδε ἀφῖξαι, ὦ Κρίτων; ἢ οὐ πρῲ ἔτ...          376
# 538   ΕΧ. αὐτός, ὦ Φαίδων, παρεγένου Σωκράτει ἐκείν...         1441
# 539  ΕΡΜ. βούλει οὖν καὶ Σωκράτει τῷδε ἀνακοινωσώμε...         2260
#
#                                   lemmatized_sentences  \
# 535  [[ευθ], [νέος, Σωκράτης, γίγνομαι, λύκειον, κα...
# 536  [[ἀνήρ, Ἀθηναῖος, πάσχω, ἐμός, κατήγορος, οἶδα...
# 537  [[σός], [ἀφικνέομαι, κριτής], [εἰμί], [κρ], []...
# 538  [[εχ], [αὐτός, φαίδων, παραγίγνομαι, Σωκράτης,...
# 539  [[ερμ], [βούλομαι, Σωκράτης, ἀνακοινόω, λόγος]...
#
#                                                lemmata  lemmata_wordcount  \
# 535  [ευθ, νέος, Σωκράτης, γίγνομαι, λύκειον, καταλ...               2420
# 536  [ἀνήρ, Ἀθηναῖος, πάσχω, ἐμός, κατήγορος, οἶδα,...               3990
# 537  [σός, ἀφικνέομαι, κριτής, εἰμί, κρ, σός, κρ, ὄ...               1887
# 538  [εχ, αὐτός, φαίδων, παραγίγνομαι, Σωκράτης, ἐκ...               9900
# 539  [ερμ, βούλομαι, Σωκράτης, ἀνακοινόω, λόγος, κρ...               8950
#
#                                           lemmata_repl  \
# 535  [ευθ, νέος, Σωκράτης, γίγνομαι, λύκειον, καταλ...
# 536  [ἀνήρ, Ἀθηναῖος, πάσχω, ἐμός, κατήγορος, οἶδα,...
# 537  [σός, ἀφικνέομαι, κριτής, εἰμί, κρ, σός, κρ, ὄ...
# 538  [εχ, αὐτός, φαίδων, παραγίγνομαι, Σωκράτης, ἐκ...
# 539  [ερμ, βούλομαι, Σωκράτης, ἀνακοινόω, λόγος, κρ...
#
#                              lemmatized_sentences_repl
# 535  [[ευθ], [νέος, Σωκράτης, γίγνομαι, λύκειον, κα...
# 536  [[ἀνήρ, Ἀθηναῖος, πάσχω, ἐμός, κατήγορος, οἶδα...
# 537  [[σός], [ἀφικνέομαι, κριτής], [εἰμί], [κρ], []...
# 538  [[εχ], [αὐτός, φαίδων, παραγίγνομαι, Σωκράτης,...
# 539  [[ερμ], [βούλομαι, Σωκράτης, ἀνακοινόω, λόγος]...

# %%
# explore how the dialogue usually looks like in a form of lemmatized sentences...
c_platonicum["lemmatized_sentences_repl"].tolist()[0]
# Out:
# [['ευθ'],
#  ['νέος',
#   'Σωκράτης',
#   'γίγνομαι',
#   'λύκειον',
#   'καταλείπω',
#   'διατριβή',
#   'διατρίβω',
#   'βασιλεύς',
#   'στοά'],
#  ['δίκη', 'τυγχάνω', 'βασιλεύς'],
#  ['σός'],
#  ['Ἀθηναῖος', 'εὐθύφρων', 'δίκη', 'αὐτός', 'καλέω', 'γραφή'],
#  ['ευθ'],
#  ['φημί'],
#  ['γραφή', 'ἔοικα', 'γράφω'],
#  ['ἐκεῖνος', 'καταγιγνώσκω', 'ἕτερος'],
#  ['σός'],
#  [],
#  ['ευθ'],
#  ['ἄλλος'],
#  ['σός'],
#  [],
#  ['ευθ'],
#  ['οὗτος'],
#  ['σός'],
#  ['αὐτός', 'γιγνώσκω', 'εὐθύφρων', 'ἀνήρ', 'νέος', 'φαίνω', 'ἀγνώς'],
#  ['ὀνομάζω', 'οἴομαι', 'μέλω'],
#  ['δῆμος',
#   'πιτθεύς',
#   'νόος',
#   'ἔχω',
#   'πιτθέα',
#   'μέλω',
#   'τετανόθριξ',
#   'εὐγένειος',
#   'ἐπίγρυπος'],
#  ['ευθ'],
#  ['ἐννοέω', 'Σωκράτης'],
#  ['γραφή', 'γράφω'],
#  ['σός'],
#  ['ὅστις'],
#  ['ἀγεννής', 'δοκέω'],
#  ['νέος', 'εἰμί', 'τοσοῦτος', 'πρᾶγμα', 'γιγνώσκω', 'φαῦλος', 'εἰμί'],
#  ['ἐκεῖνος', 'φημί', 'οἶδα', 'τρόπος', 'νέος', 'διαφθείρω', 'διαφθείροντες'],
#  ['κινδυνεύω',
#   'σοφός',
#   'εἰμί',
#   'ἐμός',
#   'ἀμαθία',
#   'κατιδὼν',
#   'διαφθείροντος',
#   'ἡλικιώτης',
#   'ἔρχομαι',
#   'κατηγορέω',
#   'μήτηρ',
#   'πόλις'],
#  ['φαίνω', 'πολιτικός', 'μόνος', 'ἄρχω'],
#  ['νέος',
#   'πρῶτος',
#   'ἐπιμελέομαι',
#   'εἰμί',
#   'ἀγαθός',
#   'γεωργός',
#   'ἀγαθός',
#   'νέος',
#   'φυτόν',
#   'ἔοικα',
#   'πρῶτος',
#   'ἐπιμελέομαι',
#   'ἄλλος'],
#  ['σός'],
#  ['μέλητος', 'πρῶτος', 'ἐκκαθαίρω', 'νέος', 'βλάστη', 'διαφθείρω', 'φημί'],
#  ['οὗτος',
#   'δῆλος',
#   'πρέσβυς',
#   'ἐπιμεληθεὶς',
#   'πολύς',
#   'μέγας',
#   'ἀγαθός',
#   'αἴτιος',
#   'πόλις',
#   'γίγνομαι',
#   'ἔοικα',
#   'συμβαίνω',
#   'τοιοῦτος',
#   'ἀρχή',
#   'ἀρξαμένῳ'],
#  ['ευθ'],
#  ['βούλομαι', 'Σωκράτης', 'ὀρρωδέω', 'γίγνομαι'],
#  ['δοκέω', 'Ἑστιάς', 'ἄρχω', 'κακουργέω', 'πόλις', 'ἐπίχειρον', 'ἀδικέω'],
#  ['λέγω', 'ποιέω', 'φημί', 'διαφθείρω', 'νέος'],
#  ['σός'],
#  ['ἄτοπος', 'θαυμάσιος', 'ἀκούω'],
#  ['φημί',
#   'ποιητής',
#   'εἰμί',
#   'θεός',
#   'καινός',
#   'ποιέω',
#   'θεός',
#   'ἀρχαῖος',
#   'νομίζοντα',
#   'γράφω',
#   'φημί'],
#  ['ευθ'],
#  ['μανθάνω', 'Σωκράτης'],
#  ['δαιμόνιον', 'φημί', 'γίγνομαι'],
#  ['καινοτομοῦντός',
#   'θεῖος',
#   'γράφω',
#   'οὗτος',
#   'γραφή',
#   'διαβαλῶν',
#   'ἔρχομαι',
#   'δικαστήριον',
#   'οἶδα',
#   'εὐδιάβολος',
#   'τοιοῦτος',
#   'πολύς'],
#  ['λέγω', 'ἐκκλησία', 'θεῖος', 'προλέγων', 'μέλλω', 'καταγελάω', 'μαινομένου'],
#  ['οὐδείς', 'ἀληθής', 'λέγω', 'προλέγω', 'φθονέω', 'πᾶς', 'τοιοῦτος'],
#  ['χρή', 'φροντίζω', 'εἶμι'],
#  ['σός'],
#  ['φίλος', 'εὐθύφρων', 'καταγελάω', 'οὐδείς', 'πρᾶγμα'],
#  ['Ἀθήναιος',
#   'δοκέω',
#   'μέλει',
#   'δεινός',
#   'οἰόομαι',
#   'εἰμί',
#   'διδασκαλικός',
#   'ἑαυτοῦ',
#   'σοφία'],
#  ['ἄλλος',
#   'οἰόομαι',
#   'ποιέω',
#   'τοιοῦτος',
#   'θυμόω',
#   'εἰμί',
#   'φθόνος',
#   'λέγω',
#   'ἄλλος'],
#  ['ευθ'],
#  ['οὗτος', 'ἔχω', 'ἐπιθυμέω', 'πειράω'],
#  ['σός'],
#  ['δοκέω', 'σπάνιος', 'παρέχω', 'διδάσκω', 'ἐθέλω', 'σοφία'],
#  ['φοβέω',
#   'φιλανθρωπία',
#   'δοκέω',
#   'ἔχω',
#   'πᾶς',
#   'ἀνήρ',
#   'λέγω',
#   'μόνος',
#   'μισθός',
#   'προστίθημι',
#   'ἐθέλω',
#   'ἀκούω'],
#  ['λέγω',
#   'μέλλω',
#   'καταγελάω',
#   'φημί',
#   'οὐδείς',
#   'εἰμί',
#   'ἀηδής',
#   'παίζοντας',
#   'γελάω',
#   'δικαστήριον',
#   'διάγω'],
#  ['σπουδάζω', 'οὗτος', 'ἀποβαίνω', 'ἄδηλος', 'μάντις'],
#  ['ευθ'],
#  ['οὐδείς',
#   'εἰμί',
#   'Σωκράτης',
#   'πρᾶγμα',
#   'νόος',
#   'ἀγωνίζομαι',
#   'δίκη',
#   'οἴομαι',
#   'ἐμός'],
#  ['σός'],
#  ['εὐθύφρων', 'δίκη'],
#  ['φεύγω', 'αὐτός', 'διώκω'],
#  ['ευθ'],
#  ['διώκω'],
#  ['σός'],
#  [],
#  ['ευθ'],
#  ['διώκω', 'δοκέω', 'μαίνομαι'],
#  ['σός'],
#  [],
#  ['πέτομαι', 'διώκω'],
#  ['ευθ'],
#  ['πολύς', 'δεῖ', 'πέτομαι', 'τυγχάνω', 'εἰμί', 'πρεσβύτης'],
#  ['σός'],
#  ['οὗτος'],
#  ['ευθ'],
#  ['ἐμός', 'πατήρ'],
#  ['σός'],
#  ['σός', 'βέλτιστος'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ἔγκλημα', 'δίκη'],
#  ['ευθ'],
#  ['φόνος', 'Σωκράτης'],
#  ['σός'],
#  ['Ἡρακλέης'],
#  ['εὐθύφρων', 'ἀγνοέω', 'πολύς', 'ἔχω'],
#  ['οἴομαι', 'ἐπιτυχόντος', 'πράσσω', 'σοφία', 'ἐλαύνοντος'],
#  ['ευθ'],
#  ['Ζεύς', 'Σωκράτης'],
#  ['σός'],
#  ['οἰκεῖος', 'τὶς', 'θνήσκω', 'σός', 'πατήρ'],
#  ['δῆλος'],
#  ['ἀλλότριος', 'ἐξίημι', 'φόνος'],
#  ['ευθ'],
#  ['γέλοιος',
#   'Σωκράτης',
#   'οἴομαι',
#   'διαφέρω',
#   'ἀλλότριος',
#   'οἰκεῖος',
#   'τεθνεώς',
#   'μόνος',
#   'δεῖ',
#   'φυλάσσω',
#   'δίκη',
#   'κτείνω',
#   'κτείνω',
#   'δίκη',
#   'ἐάω',
#   'ἐπέξειμι',
#   'κτείνω',
#   'συνέστιος',
#   'ὁμοτράπεζος',
#   'εἰμί'],
#  ['ἴσος',
#   'μίασμα',
#   'γίγνομαι',
#   'συνίημι',
#   'σύνοιδα',
#   'ἀφοσιόω',
#   'ἐκεῖνος',
#   'δίκη',
#   'ἐπέξειμι'],
#  ['ἀποθνῄσκω', 'πελάτης', 'εἰμί', 'ἐμός', 'γεωργέω', 'Νάξος', 'θητεύω'],
#  ['παροινέω', 'ὀργίζω', 'οἰκέτης', 'ἡμέτερος', 'ἀποσφάζω'],
#  ['πατήρ',
#   'συνδέω',
#   'πούς',
#   'χείρ',
#   'καταβαλὼν',
#   'τάφρος',
#   'πέμπω',
#   'ἀνήρ',
#   'πευσόμενον',
#   'ἐξηγητής',
#   'χρή',
#   'ποιέω'],
#  ['χρόνος',
#   'δεδεμένου',
#   'ὀλιγωρέω',
#   'ἀμελέω',
#   'ἀνδροφόνος',
#   'οὐδείς',
#   'πρᾶγμα',
#   'ἀποθνήσκω',
#   'πάσχω'],
#  ['λιμός',
#   'ῥῖγος',
#   'δεσμός',
#   'ἀποθνῄσκω',
#   'ἄγγελος',
#   'ἐξηγητής',
#   'ἀφικνέομαι'],
#  ['οὗτος',
#   'ἀγανακτέω',
#   'πατήρ',
#   'ἄλλος',
#   'οἰκεῖος',
#   'ἀνδροφόνος',
#   'πατήρ',
#   'φόνος',
#   'ἐπεξέρχομαι',
#   'ἀποκτείναντι',
#   'φημί',
#   'ἀποκτείνω',
#   'ἀνδροφόνος',
#   'εἰμί',
#   'ἀποθνῄσκω',
#   'δεῖ',
#   'φροντίζω',
#   'τοιούτουἀνόσιον',
#   'εἰμί',
#   'υἱός',
#   'πατήρ',
#   'φόνος',
#   'οἶδα',
#   'Σωκράτης',
#   'θεῖος',
#   'ἔχω',
#   'ὅσιος',
#   'ἀνόσιος'],
#  ['σός'],
#  ['Ζεύς',
#   'εὐθύφρων',
#   'οἴομαι',
#   'ἐπίσταμαι',
#   'θεῖος',
#   'ἔχω',
#   'ὁσία',
#   'ἀνόσιος',
#   'πράσσω',
#   'λέγω',
#   'φοβέω',
#   'δικαζόμενος',
#   'πατήρ',
#   'ἀνόσιος',
#   'πρᾶγμα',
#   'τυγχάνω',
#   'πράττων'],
#  ['ευθ'],
#  ['οὐδείς',
#   'ὄφελος',
#   'εἰμί',
#   'Σωκράτης',
#   'διαφέρω',
#   'εὐθύφρων',
#   'πολύς',
#   'ἄνθρωπος',
#   'τοιοῦτος',
#   'πᾶς',
#   'οἶδα'],
#  ['σός'],
#  ['θαυμάσιος',
#   'εὐθύφρων',
#   'κρείσσων',
#   'εἰμί',
#   'μαθητής',
#   'σός',
#   'γίγνομαι',
#   'γραφεύς',
#   'μέλω',
#   'προκαλέω',
#   'λέγω',
#   'χρόνος',
#   'θεῖος',
#   'πολύς',
#   'ποιέω',
#   'οἶδα',
#   'ἐκεῖνος',
#   'αὐτοσχεδιάζοντά',
#   'φημί',
#   'καινοτομοῦντα',
#   'θεῖος',
#   'ἐξαμαρτάνω',
#   'μαθητής',
#   'γίγνομαι',
#   'σός',
#   'μέλω',
#   'φημί',
#   'εὐθύφρων',
#   'ὁμολογέω',
#   'σοφός',
#   'εἰμί',
#   'νομίζω',
#   'ἡγέομαι',
#   'δικάζω'],
#  ['ἐκεῖνος',
#   'διδάσκαλος',
#   'λαγχάνω',
#   'δίκη',
#   'πρότερος',
#   'πρέσβυς',
#   'διαφθείρω',
#   'ἑαυτοῦ',
#   'πατήρ',
#   'διδάσκω',
#   'ἐκεῖνος',
#   'νουθετέω',
#   'κολάζω',
#   'πείθω',
#   'ἀφίημι',
#   'δίκη',
#   'γράφω',
#   'λέγω',
#   'δικαστήριον',
#   'προκαλέω',
#   'αὐτός'],
#  ['ευθ'],
#  ['Ζεύς',
#   'Σωκράτης',
#   'ἐπιχειρέω',
#   'γράφω',
#   'εὑρίσκω',
#   'οἴομαι',
#   'σαθρός',
#   'εἰμί',
#   'πολύς',
#   'πρότερος',
#   'ἐκεῖνος',
#   'λόγος',
#   'γίγνομαι',
#   'δικαστήριον',
#   'ἐμέω'],
#  ['σός'],
#  ['φίλος',
#   'ἑταῖρος',
#   'γιγνώσκω',
#   'μαθητής',
#   'ἐπιθυμέω',
#   'γίγνομαι',
#   'σός',
#   'οἶδα',
#   'ἄλλος',
#   'τὶς',
#   'μέλητος',
#   'δοκέω',
#   'ὁράω',
#   'κατεῖδον',
#   'ἀσέβεια',
#   'γράφω'],
#  ['Ζεύς',
#   'λέγω',
#   'οἶδα',
#   'διισχυρίζομαι',
#   'ποῖος',
#   'εὐσεβής',
#   'φημί',
#   'ἀσεβής',
#   'φόνος',
#   'ἄλλος'],
#  ['ταὐτόν',
#   'πρᾶξις',
#   'ὅσιος',
#   'αὐτός',
#   'ἑαυτοῦ',
#   'ἀνόσιος',
#   'ὅσιος',
#   'πᾶς',
#   'αὐτός',
#   'ἑαυτοῦ',
#   'ὅμοιος',
#   'ἔχω',
#   'ἰδέα',
#   'ἀνοσιότης',
#   'πᾶς',
#   'μέλλω',
#   'ἀνόσιος',
#   'εἰμί'],
#  ['ευθ'],
#  ['Σωκράτης'],
#  ['σός'],
#  ['λέγω', 'φημί', 'εἰμί', 'ὅσιος', 'ἀνόσιος'],
#  ['ευθ'],
#  ['λέγω',
#   'ὅσιος',
#   'ποιέω',
#   'ἀδικέω',
#   'φόνος',
#   'ἱερόν',
#   'κλοπή',
#   'τὶς',
#   'ἄλλος',
#   'τοιοῦτος',
#   'ἐξαμαρτάνω',
#   'ἐπέξειμι',
#   'πατήρ',
#   'εἰμί',
#   'τυγχάνω',
#   'μήτηρ',
#   'ἄλλος',
#   'ἐπέξειμι',
#   'ἀνόσιος'],
#  ['Σωκράτης',
#   'θεάομαι',
#   'μέγας',
#   'λέγω',
#   'τεκμήριον',
#   'νόμος',
#   'ἔχειὃ',
#   'ἄλλος',
#   'λέγω',
#   'γιγνόμεναμὴ',
#   'ἐπιτρέπω',
#   'ἀσεβέω',
#   'τυγχάνω',
#   'εἰμί'],
#  ['ἄνθρωπος',
#   'τυγχάνω',
#   'νομίζω',
#   'Ζεύς',
#   'θεός',
#   'ἀγαθός',
#   'δίκαιος',
#   'ὁμολογέω',
#   'πατήρ',
#   'δέω',
#   'υἱός',
#   'καταπίνω',
#   'δίκη',
#   'ἐκεῖνος',
#   'ἑαυτοῦ',
#   'πατήρ',
#   'ἐκτέμνω',
#   'ἕτερος',
#   'τοιοῦτος'],
#  ['χαλεπαίνω',
#   'πατήρ',
#   'ἐπεξέρχομαι',
#   'ἀδικέω',
#   'αὐτός',
#   'ἐναντίος',
#   'λέγω',
#   'θεός',
#   'ἐμέω'],
#  ['σός'],
#  ['εὐθύφρων',
#   'οὗτος',
#   'γραφή',
#   'φεύγω',
#   'τοιοῦτος',
#   'τὶς',
#   'θεός',
#   'λέγω',
#   'ἀποδέχομαι'],
#  ['ἔοικα', 'φημί', 'ἐξαμαρτάνω'],
#  ['οὗτος', 'συνδοκέω', 'οἶδα', 'τοιοῦτος', 'ἀνάγκη', 'ἔοικα', 'συγχωρέω'],
#  ['φημί', 'αὐτός', 'ὁμολογέω', 'μηδείς', 'οἶδα'],
#  ['λέγω', 'φίλιος', 'ἡγέομαι', 'γίγνομαι'],
#  ['ευθ'],
#  ['οὗτος', 'θαυμάσιος', 'Σωκράτης', 'πολύς', 'οἶδα'],
#  ['σός'],
#  ['πόλεμος',
#   'ἡγέομαι',
#   'θεός',
#   'ἀλλήλων',
#   'ἔχθρα',
#   'δεινός',
#   'μάχη',
#   'ἄλλος',
#   'πολύς',
#   'λέγω',
#   'ποιητής',
#   'ἀγαθός',
#   'γραφεύς',
#   'ἄλλος',
#   'ἱερόν',
#   'ποικίλλω',
#   'μέγας',
#   'Παναθήναια',
#   'πέπλος',
#   'μεστός',
#   'τοιοῦτος',
#   'ποίκιλμα',
#   'ἀνάγω',
#   'ἀκρόπολις'],
#  ['οὗτος', 'ἀληθής', 'φημί', 'εἰμί', 'εὐθύφρων'],
#  ['ευθ'],
#  ['μόνος',
#   'Σωκράτης',
#   'λέγω',
#   'ἄλλος',
#   'πολύς',
#   'βούλομαι',
#   'θεῖος',
#   'διηγέομαι',
#   'ἀκούω',
#   'οἶδα',
#   'ἐκπλήσσω'],
#  ['σός'],
#  ['θαυμάζω'],
#  ['οὗτος', 'σχολή', 'διηγέομαι'],
#  ['ἔρομαι', 'πείρω', 'σαφής', 'λέγω'],
#  ['ἑταῖρος',
#   'πρότερος',
#   'διδάσκω',
#   'ἐρωτήσαντα',
#   'ὅσιος',
#   'ποτάομαι',
#   'εἰμί',
#   'λέγω',
#   'οὗτος',
#   'τυγχάνω',
#   'ὅσιος',
#   'ποιέω',
#   'φόνος',
#   'ἐπέξειμι',
#   'πατήρ'],
#  ['ευθ'],
#  ['ἀληθής', 'λέγω', 'Σωκράτης'],
#  ['σός'],
#  [],
#  ['εὐθύφρων', 'πολύς', 'φημί', 'εἰμί', 'ὅσιος'],
#  ['ευθ'],
#  ['εἰμί'],
#  ['σός'],
#  ['μιμνήσκω',
#   'οὗτος',
#   'διακελεύομαι',
#   'εἷς',
#   'διδάσκω',
#   'πολύς',
#   'ὁσία',
#   'ἐκεῖνος',
#   'αὐτός',
#   'εἶδος',
#   'ὅσιος',
#   'ὅσιος',
#   'εἰμί'],
#  ['φημί', 'ἰδέα', 'ἀνόσιος', 'ἀνόσιος', 'ὅσιος', 'ὅσιος'],
#  ['μνημονεύω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['διδάσκω',
#   'ἰδέα',
#   'εἰμί',
#   'ἐκεῖνος',
#   'ἀποβλέπων',
#   'χράω',
#   'αὐτός',
#   'παράδειγμα',
#   'τοιοῦτος',
#   'ἄλλος',
#   'πράσσω',
#   'φημί',
#   'ὅσιος',
#   'εἰμί',
#   'τοιοῦτος',
#   'φημί'],
#  ['ευθ'],
#  ['βούλομαι', 'Σωκράτης', 'φράζω'],
#  ['σός'],
#  ['βούλομαι'],
#  ['ευθ'],
#  ['θεός', 'προσφιλής', 'ὅσιος', 'προσφιλής', 'ἀνόσιος'],
#  ['σός'],
#  ['εὐθύφρων', 'ζητέω', 'ἀποκρίνω', 'ἀποκρίνω'],
#  ['οἶδα', 'δῆλος', 'ἐπεκδιδάσκω', 'ἀληθής', 'λέγω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['φέρω', 'ἐπισκέπτομαι', 'λέγω'],
#  ['θεοφιλής',
#   'θεοφιλής',
#   'ἄνθρωπος',
#   'ὅσιος',
#   'θεομισής',
#   'θεομισής',
#   'ἀνόσιος'],
#  ['ταὐτός', 'εἰμί', 'ἐναντίος', 'ὅσιος', 'ἀνόσιος'],
#  [],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['φαίνω', 'λέγω'],
#  ['ευθ'],
#  ['δοκέω', 'Σωκράτης'],
#  ['λέγω'],
#  ['σός'],
#  ['στασιάζω', 'θεός', 'εὐθύφρων', 'διαφέρω', 'ἔχθρα', 'λέγω'],
#  ['ευθ'],
#  ['λέγω'],
#  ['σός'],
#  ['ἔχθρα', 'ὀργή', 'ἄριστος', 'διαφορά', 'ποιέω'],
#  ['σκοπέω'],
#  ['διαφέρω',
#   'ἀριθμός',
#   'ὁπότερος',
#   'πολύς',
#   'διαφορά',
#   'ἐχθρός',
#   'ποιέω',
#   'ὀργίζω',
#   'λογισμός',
#   'ἔρχομαι',
#   'τοιοῦτος',
#   'ταχύς',
#   'ἀπαλλάσσω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['μέγας',
#   'ἐλάσσων',
#   'διαφέρω',
#   'μετρέω',
#   'ἔρχομαι',
#   'ταχύς',
#   'παύω',
#   'διαφορά'],
#  ['ευθ'],
#  ['εἰμί'],
#  ['σός'],
#  ['ἵστημι', 'ἔρχομαι', 'οἴομαι', 'βαρύς', 'κοῦφος', 'διακρίνω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['διενεχθέντες',
#   'κρίσις',
#   'δύναμαι',
#   'ἀφικνέομαι',
#   'ἐχθρός',
#   'εἰμί',
#   'ὀργίζω'],
#  ['πρόχειρος',
#   'εἰμί',
#   'λέγω',
#   'σκοπέω',
#   'ὅδε',
#   'δίκαιος',
#   'ἄδικος',
#   'καλός',
#   'αἰσχρός',
#   'ἀγαθός',
#   'κακός'],
#  ['οὗτος',
#   'διενεχθέντες',
#   'δύναμαι',
#   'ἱκανός',
#   'κρίσις',
#   'ἔρχομαι',
#   'ἐχθρός',
#   'γίγνομαι',
#   'γίγνομαι',
#   'ἄλλος',
#   'ἄνθρωπος',
#   'πᾶς'],
#  ['ευθ'],
#  ['διαφορά', 'Σωκράτης'],
#  ['σός'],
#  ['θεός', 'εὐθύφρων'],
#  ['διαφέρω', 'αὐτός', 'οὗτος', 'διαφέρω'],
#  ['ευθ'],
#  ['πολύς', 'ἀνάγκη'],
#  ['σός'],
#  ['θεός',
#   'γενναῖος',
#   'εὐθύφρων',
#   'ἄλλος',
#   'ἄλλος',
#   'δίκαιος',
#   'ἡγέομαι',
#   'σός',
#   'λόγος',
#   'καλός',
#   'αἰσχρός',
#   'ἀγαθός',
#   'κακός'],
#  ['στασιάζω', 'διαφέρω'],
#  [],
#  [],
#  ['λέγω'],
#  ['σός'],
#  ['καλός',
#   'ἡγέομαι',
#   'ἕκαστος',
#   'ἀγαθός',
#   'δίκαιος',
#   'οὗτος',
#   'φιλέω',
#   'ἐναντίος',
#   'μισέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ταὐτός',
#   'φημί',
#   'δίκαιος',
#   'ἡγέομαι',
#   'ἄδικος',
#   'ἀμφισβητέω',
#   'στασιάζω',
#   'πολεμόω'],
#  [],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ταὐτάζω',
#   'ἔοικα',
#   'μισέω',
#   'θεός',
#   'φιλέω',
#   'θεομισής',
#   'θεοφιλής',
#   'ταὐτάζω',
#   'εἰμί'],
#  ['ευθ'],
#  ['ἔοικα'],
#  ['σός'],
#  ['ὅσιος', 'ἀνόσιος', 'αὐτός', 'εἰμί', 'εὐθύφρων', 'οὗτος', 'λόγος'],
#  ['ευθ'],
#  ['κινδυνεύω'],
#  ['σός'],
#  ['ἔρομαι', 'ἀποκρίνω', 'θαυμάσιος'],
#  ['οὗτος', 'ἐρωτάω', 'τυγχάνω', 'ταὐτός', 'ὅσιος', 'ἀνόσιος'],
#  ['θεοφιλής', 'εἰμί', 'θεομισής', 'εἰμί', 'ἔοικα'],
#  ['εὐθύφρων',
#   'ποιέω',
#   'πατήρ',
#   'κολάζων',
#   'θαυμαστός',
#   'οὗτος',
#   'δράω',
#   'Ζεύς',
#   'προσφιλής',
#   'ποιέω',
#   'Κρόνος',
#   'οὐρανός',
#   'ἐχθρός',
#   'Ἥφαιστος',
#   'φίλος',
#   'Ἥρα',
#   'ἐχθρός',
#   'ἄλλος',
#   'θεός',
#   'ἕτερος',
#   'ἕτερος',
#   'διαφέρω',
#   'αὐτός'],
#  ['ευθ'],
#  ['οἴομαι',
#   'Σωκράτης',
#   'οὗτος',
#   'θεός',
#   'ἕτερος',
#   'ἕτερος',
#   'διαφέρω',
#   'δεῖ',
#   'δίκη',
#   'δίδωμι',
#   'ἐκεῖνος',
#   'ἀποκτείνω'],
#  ['σός'],
#  [],
#  ['ἄνθρωπος',
#   'εὐθύφρων',
#   'ἀκούω',
#   'ἀμφισβητοῦντος',
#   'ἀποκτείναντα',
#   'ἄλλος',
#   'ποιέω',
#   'δεῖ',
#   'δίκη',
#   'δίδωμι'],
#  ['ευθ'],
#  ['οὐδείς', 'παύω', 'οὗτος', 'ἀμφισβητέω', 'δικαστήριον'],
#  ['ἀδικοῦντες', 'πάμπολλα', 'πᾶς', 'ποιέω', 'λέγω', 'φεύγω', 'δίκη'],
#  ['σός'],
#  ['ὁμολογέω',
#   'εὐθύφρων',
#   'ἀδικέω',
#   'ὁμολογοῦντες',
#   'δεῖ',
#   'φημί',
#   'δίδωμι',
#   'δίκη'],
#  ['ευθ'],
#  ['οὗτος'],
#  ['σός'],
#  ['πᾶς', 'ποιέω', 'λέγω'],
#  ['οὗτος',
#   'οἴομαι',
#   'τολμάω',
#   'λέγω',
#   'ἀμφισβητέω',
#   'ἀδικέω',
#   'δοτέος',
#   'δίκη',
#   'οἴομαι',
#   'φημί',
#   'ἀδικέω'],
#  [],
#  ['ευθ'],
#  ['ἀληθής', 'λέγω'],
#  ['σός'],
#  ['ἐκεῖνος',
#   'ἀμφισβητέω',
#   'ἀδικοῦντα',
#   'δεῖ',
#   'δίδωμι',
#   'δίκη',
#   'ἐκεῖνος',
#   'ἀμφισβητέω',
#   'ἀδικέω',
#   'δράω'],
#  ['ευθ'],
#  ['ἀληθής', 'λέγω'],
#  ['σός'],
#  ['οὗτος',
#   'θεός',
#   'πάσχω',
#   'στασιάζω',
#   'δίκαιος',
#   'ἄδικος',
#   'σός',
#   'λόγος',
#   'φημί',
#   'ἀλλήλων',
#   'ἀδικέω',
#   'φημί'],
#  ['ἐκεῖνος',
#   'θαυμάσιος',
#   'οὐδείς',
#   'θεός',
#   'ἄνθρωπος',
#   'τολμάω',
#   'λέγω',
#   'ἀδικέω',
#   'δοτέος',
#   'δίκη'],
#  ['ευθ'],
#  ['οὗτος', 'ἀληθής', 'λέγω', 'Σωκράτης', 'κεφάλαιος'],
#  ['σός'],
#  ['ἕκαστος',
#   'οἴομαι',
#   'εὐθύφρων',
#   'πράσσω',
#   'ἀμφισβητέω',
#   'ἀμφισβητέω',
#   'ἄνθρωπος',
#   'θεός',
#   'ἀμφισβητέω',
#   'θεός'],
#  ['πράξεώς', 'τὶς', 'διαφερόμενοι', 'φημί', 'πράσσω'],
#  [],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['εἶμι',
#   'φίλος',
#   'εὐθύφρων',
#   'διδάσκω',
#   'σοφός',
#   'γίγνομαι',
#   'τεκμήριον',
#   'πᾶς',
#   'θεός',
#   'ἡγέομαι',
#   'ἐκεῖνος',
#   'θνῄσκω',
#   'θητεύων',
#   'ἀνδροφόνος',
#   'γίγνομαι',
#   'συνδεθεὶς',
#   'δεσπότης',
#   'ἀποθνῄσκω',
#   'φθάζω',
#   'τελευτάω',
#   'δεσμός',
#   'συνδήσαντα',
#   'ἐξηγητής',
#   'πυνθάνομαι',
#   'χρή',
#   'ποιέω',
#   'τοιοῦτος',
#   'ἔχω',
#   'ἐπέξειμι',
#   'ἐπισκήπτω',
#   'φόνος',
#   'υἱός',
#   'πατήρ'],
#  ['εἶμι',
#   'πείρω',
#   'σαφής',
#   'ἐνδείκνυμι',
#   'πᾶς',
#   'πᾶς',
#   'θεός',
#   'ἡγέομαι',
#   'ἔχω',
#   'οὗτος',
#   'πρᾶξις'],
#  ['ἐνδείκνυμι', 'ἐγκωμιάζων', 'σοφία', 'παύω'],
#  ['ευθ'],
#  ['ὀλίγος', 'ἔργον', 'εἰμί', 'Σωκράτης', 'ἔχω', 'ἐπιδείκνυμι'],
#  ['σός'],
#  ['μανθάνω'],
#  ['δοκέω',
#   'δικαστής',
#   'δυσμαθής',
#   'εἰμί',
#   'ἐνδείκνυμι',
#   'δῆλος',
#   'ἄδικος',
#   'θεός',
#   'ἅπας',
#   'τοιοῦτος',
#   'μισέω'],
#  ['ευθ'],
#  ['Σωκράτης', 'ἀκούω', 'λέγω'],
#  ['σός'],
#  ['ἀκούω'],
#  ['δοκέω', 'λέγω'],
#  ['ὅδε', 'ἐννοέω', 'λέγω', 'σκοπέω'],
#  ['εὐθύφρων',
#   'διδάσκω',
#   'θεός',
#   'ἅπας',
#   'θάνατος',
#   'ἡγέομαι',
#   'ἄδικος',
#   'εἰμί',
#   'μανθάνω',
#   'εὐθύφρων',
#   'ποτός',
#   'ὅσιος',
#   'ἀνόσιος'],
#  ['θεομισής', 'ἔργον', 'ἔοικα', 'εἰμί'],
#  ['οὗτος', 'φαίνω', 'ὡρισμένα', 'ὅσιος'],
#  ['θεομισής', 'θεοφιλής', 'φαίνω'],
#  ['οὗτος', 'ἀφίημι', 'εὐθύφρων'],
#  ['βούλομαι', 'πᾶς', 'αὐτός', 'ἡγέομαι', 'θεός', 'ἄδικος', 'πᾶς', 'μισέω'],
#  ['οὗτος',
#   'ἐπανορθόω',
#   'λόγῳὡς',
#   'θεός',
#   'μισέω',
#   'ἀνόσιος',
#   'εἰμί',
#   'φιλέω',
#   'ὅσιος'],
#  ['φιλέω',
#   'μισέω',
#   'οὐδέτερος',
#   'ἀμφότεραἆρʼ',
#   'βούλομαι',
#   'ὁρίζω',
#   'ὅσιος',
#   'ἀνόσιος'],
#  ['ευθ'],
#  ['κωλύω', 'Σωκράτης'],
#  ['σός'],
#  ['οὐδείς',
#   'εὐθύφρων',
#   'σός',
#   'σκοπέω',
#   'ὑποτίθημι',
#   'ῥᾴδιος',
#   'διδάσκω',
#   'ὑπισχνέομαι'],
#  ['ευθ'],
#  ['φημί',
#   'οὗτος',
#   'ὅσιος',
#   'πᾶς',
#   'θεός',
#   'φιλέω',
#   'πᾶς',
#   'θεός',
#   'μισέω',
#   'ἀνόσιος'],
#  ['σός'],
#  ['ἐπισκοπέω',
#   'εὐθύφρων',
#   'λέγω',
#   'ἐάω',
#   'ἀποδέχομαι',
#   'ἄλλος',
#   'μόνος',
#   'φημί',
#   'ἔχω',
#   'συγχωροῦντες',
#   'ἔχω'],
#  ['σκεπτέος', 'λέγω', 'λέγω'],
#  ['ευθ'],
#  ['σκεπτέος'],
#  ['οἴομαι', 'οὗτος', 'λέγω'],
#  ['σός'],
#  ['ταχύς', 'ἀγαθός', 'βελτίων', 'οἶδα'],
#  ['ἐννοέω'],
#  ['ὅσιος', 'ὅσιος', 'φιλέω', 'θεός', 'φιλέω', 'ὅσιος', 'εἰμί'],
#  [],
#  ['οἶδα', 'λέγω', 'Σωκράτης'],
#  ['σός'],
#  ['πειράζω', 'σαφής', 'φράζω'],
#  ['λέγω',
#   'τὶς',
#   'φέρω',
#   'φέρω',
#   'ἄγω',
#   'ἄγω',
#   'ὁρώμενον',
#   'ὁράω',
#   'τοιοῦτος',
#   'μανθάνω',
#   'ἕτερος',
#   'ἕτερος'],
#  ['ευθ'],
#  ['δοκέω', 'μανθάνω'],
#  ['σός'],
#  ['φιλούμενόν', 'οὗτος', 'ἕτερος', 'φιλέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['λέγω', 'φέρω', 'φέρω', 'φέρω', 'εἰμί', 'ἄλλος'],
#  [],
#  [],
#  ['σός'],
#  ['ἄγω', 'ἄγω', 'ὁρώμενον', 'ὁράω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ὁρώμενόν', 'εἰμί', 'ὁράω', 'ὁράω', 'ὁρώμενον'],
#  ['ἄγω', 'εἰμί', 'ἄγω', 'ἄγω', 'ἄγω'],
#  ['φέρω', 'φέρω', 'φέρω', 'φέρω'],
#  ['κατάδηλος', 'εὐθύφρων', 'βούλομαι', 'λέγω'],
#  ['βούλομαι',
#   'γίγνομαι',
#   'πάσχω',
#   'γίγνομαι',
#   'εἰμί',
#   'γίγνομαι',
#   'γίγνομαι',
#   'γίγνομαι',
#   'εἰμί'],
#  ['πάσχω', 'εἰμί', 'πάσχω', 'πάσχω', 'πάσχω', 'εἰμί'],
#  ['συγχωρέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['φιλούμενον', 'γίγνομαι', 'πάσχω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['οὗτος', 'ἔχω', 'πρότερος'],
#  ['φιλούμενόν', 'φιλέω', 'φιλέω', 'φιλέω', 'φιλούμενον'],
#  ['ευθ'],
#  ['ἀνάγκη'],
#  ['σός'],
#  ['λέγω', 'ὅσιος', 'εὐθύφρων'],
#  ['ἄλλος', 'φιλέω', 'θεός', 'πᾶς', 'σός', 'λόγος'],
#  [],
#  [],
#  ['σός'],
#  ['ὅσιος', 'εἰμί', 'ἄλλος'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ὅσιος', 'εἰμί', 'φιλέω', 'φιλέω', 'ὅσιος', 'εἰμί'],
#  ['ευθ'],
#  ['ἔοικα'],
#  ['σός'],
#  ['φιλέω', 'θεός', 'φιλούμενόν', 'εἰμί', 'θεοφιλής'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['θεοφιλής',
#   'ὅσιος',
#   'εἰμί',
#   'εὐθύφρων',
#   'ὅσιος',
#   'θεοφιλής',
#   'λέγω',
#   'ἕτερος'],
#  ['ευθ'],
#  ['Σωκράτης'],
#  ['σός'],
#  ['ὁμολογέω', 'ὅσιος', 'φιλέω', 'ὅσιος', 'εἰμί', 'φιλέω', 'ὅσιος', 'εἰμί'],
#  [],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['θεοφιλής',
#   'φιλέω',
#   'θεός',
#   'αὐτός',
#   'οὗτος',
#   'φιλέω',
#   'θεοφιλής',
#   'εἰμί',
#   'θεοφιλής',
#   'φιλέω'],
#  ['ευθ'],
#  ['ἀληθής', 'λέγω'],
#  ['σός'],
#  ['ταὐτός',
#   'εἰμί',
#   'φίλος',
#   'εὐθύφρων',
#   'θεοφιλής',
#   'ὅσιος',
#   'ὅσιος',
#   'εἰμί',
#   'φιλέω',
#   'ὅσιος',
#   'θεοφιλής',
#   'φιλέω',
#   'θεοφιλής',
#   'φιλέω',
#   'θεός',
#   'θεοφιλής',
#   'θεοφιλής',
#   'εἰμί',
#   'ὅσιος',
#   'φιλέω',
#   'ὅσιος',
#   'εἰμί'],
#  ['ὁράω', 'ἔχω', 'ἕτερος', 'ὄντε', 'ἀλλήλων'],
#  ['φιλέω', 'εἰμί', 'οἷος', 'φιλέω'],
#  ['εἰμί', 'οἷος', 'φιλέω', 'φιλέω'],
#  ['κινδυνεύω',
#   'εὐθύφρων',
#   'ἐρωτώμενος',
#   'ὅσιος',
#   'ποτάομαι',
#   'εἰμί',
#   'οὐσία',
#   'βούλομαι',
#   'δηλόω',
#   'πάθος',
#   'λέγω',
#   'πάσχω',
#   'οὗτος',
#   'ὅσιος',
#   'φιλέω',
#   'πᾶς',
#   'θεός'],
#  ['ὄν', 'λέγω'],
#  ['φίλος',
#   'ἀποκρύπτω',
#   'λέγω',
#   'ἀρχή',
#   'ὅσιος',
#   'φιλέω',
#   'θεός',
#   'οὗτος',
#   'διοισόμεθαἀλλʼ',
#   'λέγω',
#   'ὅσιος',
#   'ἀνόσιος'],
#  ['ευθ'],
#  ['Σωκράτης', 'ἔχω', 'λέγω', 'νοέω'],
#  ['περιέρχομαι', 'προτίθημι', 'ἐθέλω', 'μένω', 'ἱδρύω', 'αὐτός'],
#  ['σός'],
#  ['ἡμέτερος', 'πρόγονος', 'εὐθύφρων', 'ἔοικα', 'εἰμί', 'Δαίδαλος', 'λέγω'],
#  ['λέγω',
#   'τίθημι',
#   'ἐπισκώπτω',
#   'ἐκεῖνος',
#   'συγγένεια',
#   'λόγος',
#   'ἔργον',
#   'ἀποδιδράσκω',
#   'ἐθέλω',
#   'μένω',
#   'αὐτός',
#   'τίθημι'],
#  ['σός', 'ὑπόθεσις', 'εἰμί'],
#  ['ἄλλος', 'δεῖ', 'σκῶμμα'],
#  ['ἐθέλω', 'μένω', 'αὐτός', 'δοκέω'],
#  ['ευθ'],
#  ['δοκέω', 'σκῶμμα', 'Σωκράτης', 'δέω', 'λέγω'],
#  ['ἵημι', 'οὗτος', 'μένω', 'εἰμί', 'ἐντίθημι', 'δοκέω', 'Δαίδαλος', 'μένω'],
#  ['σός'],
#  ['κινδυνεύω',
#   'ἑταῖρος',
#   'ἐκεῖνος',
#   'ἀνήρ',
#   'δεινός',
#   'γίγνομαι',
#   'τέχνη',
#   'τοσοῦτος',
#   'ἑαυτοῦ',
#   'μόνος',
#   'ποιέω',
#   'μένω',
#   'ἔοικα',
#   'ἀλλότριος'],
#  ['οὗτος', 'τέχνη', 'εἰμί', 'κομψός', 'ἄκων', 'εἰμί', 'σοφός'],
#  ['βούλομαι',
#   'λόγος',
#   'μένω',
#   'ἱδρύω',
#   'Δαίδαλος',
#   'σοφία',
#   'Τάνταλος',
#   'χρῆμα',
#   'γίγνομαι'],
#  ['οὗτος'],
#  ['δοκέω',
#   'τρυφάω',
#   'αὐτός',
#   'συμπροθυμέομαι',
#   'δείκνυμι',
#   'διδάσκω',
#   'ὅσιος'],
#  ['προαποκάμνω'],
#  ['ἀναγκαῖος', 'δοκέω', 'δίκαιος', 'εἰμί', 'πᾶς', 'ὅσιος'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['πᾶς', 'δίκαιος', 'ὅσιος'],
#  ['ὅσιος', 'πᾶς', 'δίκαιος', 'δίκαιος', 'πᾶς', 'ὅσιος', 'ὅσιος', 'ἄλλος'],
#  ['ευθ'],
#  ['ἕπομαι', 'Σωκράτης', 'λέγω'],
#  ['σός'],
#  ['νέος', 'ἐλάσσων', 'ὅσος', 'σοφός'],
#  ['λέγω', 'τρυφή', 'πλοῦτος', 'σοφία'],
#  ['μακάριος', 'συντείνω', 'σαυτόν'],
#  ['χαλεπός', 'κατανοέω', 'λέγω'],
#  ['λέγω',
#   'ποιητής',
#   'ποιέω',
#   'ἔρξαντα',
#   'ὅδε',
#   'πᾶς',
#   'φυτεύω',
#   'ἐθέλω',
#   'νεικέω'],
#  ['δέος', 'αἰδώς'],
#  [],
#  ['οὗτος', 'διαφέρω', 'ποιητός'],
#  ['λέγω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['δοκέω',
#   'δέος',
#   'αἰδώς',
#   'πολύς',
#   'δοκέω',
#   'νόσος',
#   'πενία',
#   'ἄλλος',
#   'πολύς',
#   'δεδιότες',
#   'δείδω',
#   'αἰδέομαι',
#   'οὗτος',
#   'δείδω'],
#  ['δοκέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['αἰδώς', 'δέος', 'εἰμί'],
#  ['αἰδούμενός', 'πρᾶγμα', 'αἰσχυνόμενος', 'φοβέω', 'δείδω', 'δόξα', 'πονηρία'],
#  ['ευθ'],
#  ['δείδω'],
#  ['σός'],
#  ['ἔχω', 'λέγω'],
#  ['δέος', 'αἰδώς', 'αἰδώς', 'δέος', 'δέος', 'αἰδώς'],
#  ['πολύς', 'οἴομαι', 'δέος', 'αἰδώς'],
#  ['μόριον',
#   'αἰδώς',
#   'δέος',
#   'ἀριθμός',
#   'περισσός',
#   'ἀριθμός',
#   'περισσός',
#   'περισσός',
#   'ἀριθμός'],
#  ['ἕπῃ'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['τοιοῦτος', 'λέγω', 'ἐρωτάω'],
#  ['δίκαιος', 'ὅσιος'],
#  ['ὅσιος', 'δίκαιος', 'δίκαιος', 'ὅσιος'],
#  ['μόριον', 'δίκαιος', 'ὅσιος'],
#  ['φημί', 'δοκέω'],
#  ['ευθ'],
#  [],
#  ['φαίνω', 'λέγω'],
#  ['σός'],
#  ['ὁράω'],
#  ['μέρος',
#   'ὅσιος',
#   'δίκαιος',
#   'δεῖ',
#   'ἔοικα',
#   'ἐξευρίσκω',
#   'ποῖος',
#   'μέρος',
#   'δίκαιος',
#   'ὅσιος'],
#  ['ἐρωτάω',
#   'οἷος',
#   'ποῖος',
#   'μέρος',
#   'ἀριθμός',
#   'ἄρτιος',
#   'τυγχάνω',
#   'οὗτος',
#   'ἀριθμός',
#   'λέγω',
#   'σκαληνός',
#   'εἰμί',
#   'ἰσοσκελής'],
#  ['δοκέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['πείρω',
#   'διδάσκω',
#   'ποῖος',
#   'μέρος',
#   'δίκαιος',
#   'ὅσιος',
#   'εἰμί',
#   'μελήτῳ',
#   'λέγω',
#   'ἀδικέω',
#   'ἀσέβεια',
#   'γράφω',
#   'μεμαθηκότας',
#   'εὐσεβής',
#   'ὅσιος'],
#  ['ευθ'],
#  ['οὗτος',
#   'δοκέω',
#   'Σωκράτης',
#   'μέρος',
#   'δίκαιος',
#   'εὐσεβής',
#   'ὅσιος',
#   'θεός',
#   'θεραπεία',
#   'ἄνθρωπος',
#   'λοιπός',
#   'εἰμί',
#   'δίκαιος',
#   'μέρος'],
#  ['σός'],
#  ['εὐθύφρων', 'φαίνω', 'λέγω', 'μικρός', 'ἐνδεής', 'εἰμί'],
#  ['θεραπεία', 'συνίημι', 'ὀνομάζω'],
#  ['λέγω',
#   'ἄλλος',
#   'θεραπεία',
#   'εἰμί',
#   'τοιοῦτος',
#   'θεός',
#   'λέγω',
#   'πουοἷόν',
#   'φημί',
#   'ἵππος',
#   'πᾶς',
#   'ἐπίσταμαι',
#   'θεραπεύω',
#   'ἱππικός'],
#  [],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ἱππικός', 'ἵππος', 'θεραπεία'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['κύων', 'πᾶς', 'ἐπίσταμαι', 'θεραπεύω', 'κυνηγετικός'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['κυνηγετικός', 'κύων', 'θεραπεία'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['βοηλατικός', 'βοῦς'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ὁσιότης', 'εὐσέβεια', 'θεός', 'εὐθύφρων'],
#  ['λέγω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['θεραπεία', 'πᾶς', 'ταὐτός', 'διαπράσσω'],
#  ['οἷος'],
#  ['ἀγαθός',
#   'ὠφέλεια',
#   'θεραπευομένου',
#   'ὁράω',
#   'ἵππος',
#   'ἱππικός',
#   'θεραπευόμενοι',
#   'ὠφελέω',
#   'βελτίων',
#   'γίγνομαι'],
#  ['δοκέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['κύων', 'κυνηγετικός', 'βοῦς', 'βοηλατικός', 'ἄλλος', 'πᾶς'],
#  ['βλάβη', 'οἴομαι', 'θεραπευομένου', 'θεραπεία', 'εἰμί'],
#  ['ευθ'],
#  ['Ζεύς'],
#  ['σός'],
#  ['ὠφέλεια'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ὁσιότης',
#   'θεραπεία',
#   'θεός',
#   'ὠφέλεια',
#   'θεός',
#   'βελτίων',
#   'θεός',
#   'ποιέω'],
#  ['οὗτος', 'συγχωρέω', 'ὅσιος', 'ποιέω', 'βελτίων', 'θεός', 'ἀπεργάζομαι'],
#  ['ευθ'],
#  ['Ζεύς'],
#  ['σός'],
#  ['εὐθύφρων',
#   'οἴομαι',
#   'οὗτος',
#   'λέγω',
#   'πολύς',
#   'δέωἀλλὰ',
#   'οὗτος',
#   'ἀνέρομαι',
#   'λέγω',
#   'θεραπεία',
#   'θεός',
#   'ἡγέομαι',
#   'τοιοῦτος',
#   'λέγω'],
#  ['ευθ'],
#  ['Σωκράτης'],
#  ['τοιοῦτος', 'λέγω'],
#  ['σός'],
#  ['εἰμί'],
#  ['θεός', 'θεραπεία', 'εἰμί', 'ὁσιότης'],
#  ['ευθ'],
#  ['Σωκράτης', 'δοῦλος', 'δεσπότης', 'θεραπεύω'],
#  ['σός'],
#  ['μανθάνω'],
#  ['ὑπηρετικός', 'ἔοικα', 'εἰμί', 'θεός'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ἔχω',
#   'λέγω',
#   'ἰατρός',
#   'ὑπηρετικός',
#   'ἔργον',
#   'ἀπεργασία',
#   'τυγχάνω',
#   'εἰμί',
#   'ὑπηρετικός'],
#  ['ὑγίεια', 'οἴομαι'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ναυπηγός', 'ὑπηρετικός'],
#  ['ἔργον', 'ἀπεργασία', 'ὑπηρετικός', 'εἰμί'],
#  ['ευθ'],
#  ['δῆλος', 'Σωκράτης', 'πλοῖον'],
#  ['σός'],
#  ['οἰκοδόμος', 'οἰκία'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['λέγω', 'ἄριστος'],
#  ['θεός', 'ὑπηρετικός', 'ἔργον', 'ἀπεργασία', 'ὑπηρετικός', 'εἰμί'],
#  ['δῆλος', 'εἴδω', 'θεῖος', 'καλός', 'φημί', 'οἶδα', 'ἄνθρωπος'],
#  ['ευθ'],
#  ['ἀληθής', 'λέγω', 'Σωκράτης'],
#  ['σός'],
#  ['λέγω',
#   'Ζεύς',
#   'πάγκαλος',
#   'ἔργον',
#   'θεός',
#   'ἀπεργάζομαι',
#   'ὑπηρέτης',
#   'χράω'],
#  ['ευθ'],
#  ['πολύς', 'καλός', 'Σωκράτης'],
#  ['σός'],
#  ['στρατηγός', 'φίλος'],
#  ['κεφάλαιος', 'εἶπον', 'νίκη', 'πόλεμος', 'ἀπεργάζομαι'],
#  [],
#  [],
#  [],
#  ['σός'],
#  ['πολύς', 'οἴομαι', 'καλός', 'γεωργός'],
#  ['κεφάλαιος', 'ἀπεργασία', 'γῆ', 'τροφή'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['πολύς', 'καλός', 'θεός', 'ἀπεργάζομαι'],
#  ['κεφάλαιος', 'εἰμί', 'ἐργασία'],
#  ['ευθ'],
#  ['ὀλίγος',
#   'πρότερος',
#   'λέγω',
#   'Σωκράτης',
#   'πολύς',
#   'ἔργον',
#   'ἔχω',
#   'μανθάνω'],
#  ['ὅδε',
#   'λέγω',
#   'χαρίζομαι',
#   'ἐπίσταμαι',
#   'θεός',
#   'λέγω',
#   'πράσσω',
#   'εὔχομαι',
#   'θύω',
#   'οὗτος',
#   'εἰμί',
#   'ὅσιος',
#   'σώζω',
#   'τοιοῦτος',
#   'ἴδιος',
#   'οἶκος',
#   'κοινός',
#   'πόλις'],
#  ['ἐναντίος', 'κεχαρισμένων', 'ἀσεβής', 'ἀνατρέπω', 'ἅπας', 'ἀπόλλυμι'],
#  ['σός'],
#  ['πολύς', 'βραχύς', 'εὐθύφρων', 'βούλομαι', 'λέγω', 'κεφάλαιος', 'ἐρωτάω'],
#  ['πρόθυμος', 'εἰμί', 'διδάξαιδῆλος', 'εἰμί'],
#  ['εἰμί', 'ἀποτρέπω', 'ἀποκρίνω', 'ὁσιότης', 'μανθάνω'],
#  ['ἀνάγκη',
#   'ἐρῶντα',
#   'ἐρώμενος',
#   'ἀκολουθέω',
#   'ἐκεῖνος',
#   'ὑπάγω',
#   'λέγω',
#   'ὅσιος',
#   'εἰμί',
#   'ὁσιότης'],
#  ['ἐπιστήμη', 'θύω', 'εὔχομαι'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['θύω', 'δωρέω', 'εἰμί', 'θεός', 'εὔχομαι', 'αἰτέω', 'θεός'],
#  ['ευθ'],
#  ['Σωκράτης'],
#  ['σός'],
#  ['ἐπιστήμη', 'αἴτησις', 'δόσις', 'θεός', 'ὁσιότης', 'οὗτος', 'λόγος'],
#  ['ευθ'],
#  ['Σωκράτης', 'συνίημι', 'λέγω'],
#  ['σός'],
#  ['ἐπιθυμητής',
#   'εἰμί',
#   'φίλος',
#   'σός',
#   'σοφία',
#   'προσέχω',
#   'νόος',
#   'αὐτός',
#   'πίπτω',
#   'λέγω'],
#  ['λέγω', 'ὑπηρέσιον', 'εἰμί', 'θεός'],
#  ['αἰτέω', 'φημί', 'δίδωμι'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['αἰτέω', 'δέω', 'αὐτός', 'αἰτέω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['δίδωμι', 'τυγχάνω', 'δέω', 'ἀντιδωρέομαι'],
#  ['τεχνικός', 'δωροφορέω', 'δίδωμι', 'οὗτος', 'οὐδείς', 'δέω'],
#  ['ευθ'],
#  ['ἀληθής', 'λέγω', 'Σωκράτης'],
#  ['σός'],
#  ['ἐμπορικός', 'εἰμί', 'εὐθύφρων', 'τέχνη', 'ὁσιότης', 'θεός', 'ἄνθρωπος'],
#  ['ευθ'],
#  ['ἐμπορικός', 'ἡδύς', 'ὀνομάζω'],
#  ['σός'],
#  ['οὐδείς', 'ἡδύς', 'τυγχάνω', 'ἀληθής', 'ὄν'],
#  ['φράζω', 'ὠφέλεια', 'θεός', 'τυγχάνω', 'δῶρον', 'λαμβάνω'],
#  ['δίδωμι', 'πᾶς', 'δῆλος'],
#  ['οὐδείς', 'ἀγαθός', 'δίδωμι'],
#  ['λαμβάνω', 'ὠφελέω'],
#  ['τοσοῦτος', 'πλεονεκτέω', 'ἐμπορία', 'πᾶς', 'ἀγαθός', 'λαμβάνω', 'οὐδείς'],
#  ['ευθ'],
#  ['οἴομαι', 'Σωκράτης', 'θεός', 'ὠφελέω', 'οὗτος', 'λαμβάνω'],
#  ['σός'],
#  ['εἰμί', 'εὐθύφρων', 'δῶρον', 'θεός'],
#  ['ευθ'],
#  ['οἴομαι', 'ἄλλος', 'τιμή', 'γέρας', 'λέγω', 'χάρις'],
#  ['σός'],
#  ['χαρίζω', 'εἰμί', 'εὐθύφρων', 'ὅσιος', 'ὠφέλιμος', 'φίλος', 'θεός'],
#  [],
#  ['οἴομαι', 'πᾶς', 'φίλος'],
#  ['σός'],
#  ['οὗτος', 'εἰμί', 'ἔοικα', 'ὅσιος', 'θεός', 'φίλος'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['θαυμάζω',
#   'οὗτος',
#   'λέγω',
#   'λόγος',
#   'φαίνω',
#   'μένω',
#   'βαδίζοντες',
#   'αἰτιάομαι',
#   'δαίδαλος',
#   'βαδίζοντας',
#   'ποιέω',
#   'αὐτός',
#   'εἰμί',
#   'πολύς',
#   'τεχνικός',
#   'Δαίδαλος',
#   'κύκλος',
#   'περιιόντα',
#   'ποιέω'],
#  ['αἰσθάνομαι', 'λόγος', 'περιελθὼν', 'ταὐτός', 'ἥκω'],
#  ['μιμνήσκω', 'ὅσιος', 'θεοφιλής', 'ταὐτός', 'φαίνω', 'ἕτερος', 'ἀλλήλων'],
#  ['μιμνήσκω'],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ἐννοέω', 'θεός', 'φίλος', 'φημί', 'ὅσιος', 'εἰμί'],
#  ['οὗτος', 'ἄλλος', 'θεοφιλής', 'γίγνομαι'],
#  [],
#  ['ευθ'],
#  [],
#  ['σός'],
#  ['ὁμολογέω', 'τίθημι'],
#  ['ευθ'],
#  ['ἔοικα'],
#  ['σός'],
#  ['ἀρχή',
#   'σκεπτέος',
#   'εἰμί',
#   'ὅσιος',
#   'μανθάνω',
#   'ἑκών',
#   'εἰμί',
#   'ἀποδειλιάω'],
#  ['ἀτιμάζω', 'τρόπος', 'προσέχω', 'νόος', 'λέγω', 'ἀλήθεια'],
#  ['εἴδω', 'ἄλλος', 'ἄνθρωπος', 'ἀφετέος', 'πρωτεὺς', 'λέγω'],
#  ['οἶδα',
#   'ὅσιος',
#   'ἀνόσιος',
#   'εἰμί',
#   'ἐπιχειρέω',
#   'ἀνήρ',
#   'θής',
#   'ἀνήρ',
#   'πρεσβύτης',
#   'πατήρ',
#   'διώκω',
#   'φόνος',
#   'θεός',
#   'δείδω',
#   'παρακινδυνεύω',
#   'αὐτός',
#   'ποιέω',
#   'ἄνθρωπος',
#   'αἰσχύνω'],
#  ['οἶδα', 'οἴομαι', 'οἶδα', 'ὅσιος'],
#  ['λέγω', 'βέλτιστος', 'εὐθύφρων', 'ἀποκρύπτω', 'ἡγέομαι'],
#  ['ευθ'],
#  ['Σωκράτης'],
#  ['σπεύδω', 'ὥρα', 'ἄπειμι'],
#  ['σός'],
#  ['ποιέω', 'ἑταῖρος'],
#  ['ἐλπίς',
#   'καταβαλὼν',
#   'μέγας',
#   'ἀπέρχομαι',
#   'ἔχω',
#   'μανθάνω',
#   'ὅσιος',
#   'μέλω',
#   'γραφεύς',
#   'ἀπαλλάσσω',
#   'ἐνδειξάμενος',
#   'σοφός',
#   'εὐθύφρων',
#   'θεῖος',
#   'γίγνομαι',
#   'ἄγνοια',
#   'αὐτοσχεδιάζω',
#   'καινοτομέω',
#   'ἄλλος',
#   'βίος',
#   'ἀγαθός',
#   'βιώσκομαι']]

# %% [markdown]
# # Export the data for future usage

# %%
c_hippocraticum.to_json("../data/c_hippocraticum_repl.json")
c_platonicum.to_json("../data/c_platonicum_repl.json")
c_aristotelicum.to_json("../data/c_aristotelicum_repl.json")
